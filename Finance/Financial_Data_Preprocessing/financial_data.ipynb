# %%
import pandas as pd
import yfinance as yf

# %%
df_yahoo = yf.download('AAPL', start='2000-01-01', end='2024-12-31', progress=False)

# %%
df_yahoo.head()
# Out:
# Price      Adj Close     Close      High       Low      Open     Volume
# Ticker          AAPL      AAPL      AAPL      AAPL      AAPL       AAPL
# Date
# 2000-01-03  0.843077  0.999442  1.004464  0.907924  0.936384  535796800
# 2000-01-04  0.771997  0.915179  0.987723  0.903460  0.966518  512377600
# 2000-01-05  0.783293  0.928571  0.987165  0.919643  0.926339  778321600
# 2000-01-06  0.715509  0.848214  0.955357  0.848214  0.947545  767972800
# 2000-01-07  0.749401  0.888393  0.901786  0.852679  0.861607  460734400

# %%
df_yahoo.tail()
# Out:
# Price        Adj Close       Close        High         Low        Open  \
# Ticker            AAPL        AAPL        AAPL        AAPL        AAPL
# Date
# 2024-12-23  255.270004  255.270004  255.649994  253.449997  254.770004
# 2024-12-24  258.200012  258.200012  258.209991  255.289993  255.490005
# 2024-12-26  259.019989  259.019989  260.100006  257.630005  258.190002
# 2024-12-27  255.589996  255.589996  258.700012  253.059998  257.829987
# 2024-12-30  252.199997  252.199997  253.500000  250.750000  252.229996
#
# Price         Volume
# Ticker          AAPL
# Date
# 2024-12-23  40858800
# 2024-12-24  23234700
# 2024-12-26  27237100
# 2024-12-27  42355300
# 2024-12-30  35557500

# %%
# !pip install quandl
# Out:
# ...
#   Using cached inflection-0.5.1-py2.py3-none-any.whl (9.5 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.0/63.0 kB 3.7 MB/s eta 0:00:00
# ...
#
# [notice] A new release of pip available: 22.2.1 -> 25.0
# [notice] To update, run: pip install --upgrade pip

# %%
import quandl

# %%
import numpy as np

# %%
df_yahoo = df_yahoo.loc[:, ['Adj Close']]
df_yahoo.rename(columns={'Adj Close': 'adj_close'}, inplace=True)

# %%
df_yahoo['simple_rtn'] = df_yahoo.adj_close.pct_change()
df_yahoo['log_rtn'] = np.log(df_yahoo.adj_close/df_yahoo.adj_close.shift())

# %%
df_yahoo.head()
# Out:
# Price      adj_close simple_rtn   log_rtn
# Ticker          AAPL
# Date
# 2000-01-03  0.843077        NaN       NaN
# 2000-01-04  0.771997  -0.084310 -0.088077
# 2000-01-05  0.783293   0.014633  0.014527
# 2000-01-06  0.715509  -0.086538 -0.090514
# 2000-01-07  0.749401   0.047368  0.046281

# %%
df_yahoo.tail()
# Out:
# Price        adj_close simple_rtn   log_rtn
# Ticker            AAPL
# Date
# 2024-12-23  255.270004   0.003065  0.003060
# 2024-12-24  258.200012   0.011478  0.011413
# 2024-12-26  259.019989   0.003176  0.003171
# 2024-12-27  255.589996  -0.013242 -0.013331
# 2024-12-30  252.199997  -0.013263 -0.013352

# %%
QUANDL_KEY='XaypSTHQ9JE4nNvnyz4E'
quandl.ApiConfig.api_key = QUANDL_KEY

# %%
df_all_dates = pd.DataFrame(index=pd.date_range(start='1999-12-31', end='2024-12-31'))

# %%
# !pip install statsmodels
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 961.0 kB/s eta 0:00:0000:01:010m
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.9/232.9 kB 1.1 MB/s eta 0:00:00a 0:00:01
# ...
#
# [notice] A new release of pip available: 22.2.1 -> 25.0
# [notice] To update, run: pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
import yfinance as yf
import seaborn as sns
import scipy.stats as scs
import statsmodels.api as sm
import statsmodels.tsa.api as smt

# %%
r_range = np.linspace(min(df_yahoo.log_rtn), max(df_yahoo.log_rtn), num=1000)
mu = df_yahoo.log_rtn.mean()
sigma = df_yahoo.log_rtn.std()
norm_pdf = scs.norm.pdf(r_range, loc=mu, scale=sigma)

# %%
df = yf.download('MSFT', start='2000-01-01', end='2024-12-31', progress=False)
df = df.loc[:,['Adj Close']]
df.rename(columns={'Adj Close': 'adj_close'}, inplace=True)

# %%
df['simple_rtn'] = df.adj_close.pct_change()
df['log_rtn'] = np.log(df.adj_close/df.adj_close.shift(1))

# %%
df.head()
# Out:
# Price       adj_close simple_rtn   log_rtn
# Ticker           MSFT
# Date
# 2000-01-03  35.864090        NaN       NaN
# 2000-01-04  34.652596  -0.033780 -0.034364
# 2000-01-05  35.017948   0.010543  0.010488
# 2000-01-06  33.844933  -0.033498 -0.034071
# 2000-01-07  34.287201   0.013067  0.012983

# %%
df = df_all_dates.join(df[['adj_close']], how='left').fillna(method='ffill').asfreq('M')
# Out:
# ---------------------------------------------------------------------------
# MergeError                                Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 df = df_all_dates.join(df[['adj_close']], how='left').fillna(method='ffill').asfreq('M')
#
# File ~/.pyenv/versions/3.10.6/lib/python3.10/site-packages/pandas/core/frame.py:10757, in DataFrame.join(self, other, on, how, lsuffix, rsuffix, sort, validate)
#   10747     if how == "cross":
#   10748         return merge(
#   10749             self,
#   10750             other,
#    (...)
#   10755             validate=validate,
#   10756         )
# > 10757     return merge(
#   10758         self,
#   10759         other,
#   10760         left_on=on,
#   10761         how=how,
#   10762         left_index=on is None,
#   10763         right_index=True,
#   10764         suffixes=(lsuffix, rsuffix),
#   10765         sort=sort,
#   10766         validate=validate,
#   10767     )
#   10768 else:
# ...
